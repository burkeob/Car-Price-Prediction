# %% [markdown]
# ### Testing environment

# %%
from __future__ import print_function
from packaging.version import parse as Version
from platform import python_version

OK = '\x1b[42m[ OK ]\x1b[0m'
FAIL = "\x1b[41m[FAIL]\x1b[0m"

try:
    import importlib
except ImportError:
    print(FAIL, "Python version 3.10 is required,"
                " but %s is installed." % sys.version)

def import_version(pkg, min_ver, fail_msg=""):
    mod = None
    try:
        mod = importlib.import_module(pkg)
        if pkg in {'PIL'}:
            ver = mod.VERSION
        else:
            ver = mod.__version__
        if Version(ver) == Version(min_ver):
            print(OK, "%s version %s is installed."
                  % (lib, min_ver))
        else:
            print(FAIL, "%s version %s is required, but %s installed."
                  % (lib, min_ver, ver))    
    except ImportError:
        print(FAIL, '%s not installed. %s' % (pkg, fail_msg))
    return mod


# first check the python version
pyversion = Version(python_version())

if pyversion >= Version("3.10"):
    print(OK, "Python version is %s" % pyversion)
elif pyversion < Version("3.10"):
    print(FAIL, "Python version 3.10 is required,"
                " but %s is installed." % pyversion)
else:
    print(FAIL, "Unknown Python version: %s" % pyversion)

    
print()
requirements = {'numpy': "1.22.4", 'matplotlib': "3.5.2",'sklearn': "1.1.1", 
                'pandas': "1.4.2",'xgboost': "1.5.1", 'shap': "0.40.0"}

# now the dependencies
for lib, required_version in list(requirements.items()):
    import_version(lib, required_version)
# Out:
# [ OK ] Python version is 3.10.5
#
# [ OK ] numpy version 1.22.4 is installed.
# [ OK ] matplotlib version 3.5.2 is installed.
# [ OK ] sklearn version 1.1.1 is installed.
# [ OK ] pandas version 1.4.2 is installed.
# [ OK ] xgboost version 1.5.1 is installed.
# /Users/burkeobrien/opt/anaconda3/envs/ds_env/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [ OK ] shap version 0.40.0 is installed.

# %% [markdown]
# ### Importing dataset

# %%
# Import packages

import pandas as pd
import numpy as np
from matplotlib import pylab as plt
import seaborn as sb
import dataframe_image as dfi

# %%
df = pd.read_csv("../data/audi.csv")

# %% [markdown]
# ### EDA

# %%
print(df.shape)
df.info(verbose=True)
# Out:
# (10668, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB

# %% [markdown]
# **Check for missing values**

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# **Describe Target Feature**<br>
# We will be predicting list price, but there are lots of other interesting approaches to this dataset. Price is a continuous feature, which makes this a regression problem.

# %%
d = pd.DataFrame(df['price'].describe())
print(d)
dfi.export(d, "../figures/Tables/price_description_table.png")
# Out:
#                price
# count   10668.000000
# mean    22896.685039
# std     11714.841888
# min      1490.000000
# 25%     15130.750000
# 50%     20200.000000
# 75%     27990.000000
# max    145000.000000
# objc[14683]: Class WebSwapCGLLayer is implemented in both /System/Library/Frameworks/WebKit.framework/Versions/A/Frameworks/WebCore.framework/Versions/A/Frameworks/libANGLE-shared.dylib (0x7ffb59a1b948) and /Applications/Google Chrome.app/Contents/Frameworks/Google Chrome Framework.framework/Versions/106.0.5249.119/Libraries/libGLESv2.dylib (0x1107cf668). One of the two will be used. Which one is undefined.
# [1019/121723.393347:INFO:headless_shell.cc(660)] Written to file /var/folders/0r/d390l7l966lbz2f5k72v_24h0000gn/T/tmpp82yft90/temp.png.

# %%
fig = sb.histplot(df['price']).get_figure()
plt.xlabel('Car Price')
plt.title('Price Distribution')
plt.figtext(0.1, -0.01, 'Fig. 1- Target variable distribution', wrap=True, horizontalalignment='left', fontsize=12)
plt.savefig('../figures/price_histogram.png')

# %%
sb.histplot(df['price'], cumulative = True, stat="density", fill = 'False', element="step")
plt.xlabel('Car Price')
plt.ylabel('Cumulative Density')
plt.title('Price Distribution')
plt.savefig('../figures/cumulative_price.png')

# %%
sb.histplot(np.log(df['price']))
plt.xlabel('Logged Car Price')
plt.title('Logged Price Distribution')
plt.savefig('../figures/log_price_histogram.png')

# %% [markdown]
# **Categorical Feature Descriptions**
# There are three categorical features: model, transmission, and fuelType. For each category I check the distribution and how they relate to my target variable.

# %%
len(df['model'].value_counts())
# Out:
# 26

# %%
# Some models are very rare

df['model'].value_counts()
# Out:
#  A3     1929
#  Q3     1417
#  A4     1381
#  A1     1347
#  A5      882
#  Q5      877
#  Q2      822
#  A6      748
#  Q7      397
#  TT      336
#  A7      122
#  A8      118
#  Q8       69
#  RS6      39
#  RS3      33
#  RS4      31
#  RS5      29
#  R8       28
#  S3       18
#  SQ5      16
#  S4       12
#  SQ7       8
#  S8        4
#  S5        3
#  A2        1
#  RS7       1
# Name: model, dtype: int64

# %%
# The rare models are not similar in price

df.groupby('model').mean()
# Out:
#               year         price        mileage         tax        mpg  \
# model
#  A1    2016.626578  14327.750557   24498.288048   77.171492  58.674239
#  A2    2003.000000   2490.000000  100000.000000   30.000000  65.700000
#  A3    2016.713323  17408.522032   28891.087092   95.383618  56.955106
#  A4    2016.997104  20255.450398   29690.989862  110.304127  54.360391
#  A5    2017.314059  23577.114512   23515.295918  139.427438  50.395238
#  A6    2016.684492  22695.385027   35005.590909  115.160428  54.341578
#  A7    2016.778689  28865.516393   27480.942623  158.606557  47.072131
#  A8    2017.194915  34981.847458   18256.872881  173.135593  43.949153
#  Q2    2018.423358  22516.975669   10797.816302  142.408759  47.843187
#  Q3    2017.330275  22999.261821   21194.870854  144.940014  46.101411
#  Q5    2017.421893  30445.688712   22318.257697  171.898518  42.233865
#  Q7    2017.705290  44788.319899   21672.755668  172.581864  38.701511
#  Q8    2019.028986  60115.014493    6412.043478  145.869565  32.965217
#  R8    2016.857143  97652.214286   12363.000000  296.071429  22.407143
#  RS3   2017.030303  34050.515152   25870.545455  222.121212  33.075758
#  RS4   2017.387097  50151.612903   21743.806452  251.290323  29.009677
#  RS5   2018.241379  51265.206897   11572.758621  187.758621  30.117241
#  RS6   2016.410256  55963.871795   28524.641026  285.897436  28.574359
#  RS7   2014.000000  33490.000000   56000.000000  555.000000  28.800000
#  S3    2015.111111  20379.444444   40500.722222  187.222222  41.405556
#  S4    2015.500000  31248.083333   27117.666667  210.000000  34.841667
#  S5    2012.666667  15980.000000   53606.666667  295.000000  33.900000
#  S8    2016.000000  33807.750000   29441.000000  333.750000  29.625000
#  SQ5   2016.187500  31415.812500   42114.875000  200.312500  37.937500
#  SQ7   2016.875000  49269.000000   27659.375000  203.125000  39.200000
#  TT    2016.247024  21784.452381   28146.770833  148.258929  45.481250
#
#        engineSize
# model
#  A1      1.363920
#  A2      1.400000
#  A3      1.641472
#  A4      2.013541
#  A5      2.075397
#  A6      2.220588
#  A7      2.950820
#  A8      3.092373
#  Q2      1.522749
#  Q3      1.780452
#  Q5      2.197263
#  Q7      3.207053
#  Q8      3.086957
#  R8      4.985714
#  RS3     2.500000
#  RS4     3.235484
#  RS5     3.034483
#  RS6     4.000000
#  RS7     4.000000
#  S3      1.988889
#  S4      2.550000
#  S5      3.000000
#  S8      4.000000
#  SQ5     2.625000
#  SQ7     4.000000
#  TT      1.997321

# %%
df['model'].value_counts().plot(kind='bar') 
plt.xlabel('Model')
plt.title('Count')
plt.savefig('../figures/car_model_counts.png')

# %%
d = pd.DataFrame(df['transmission'].value_counts() / len(df))
d.columns = ['Frequency']
dfi.export(d, "../figures/Tables/transmission_frequency_table.png")
# Out:
# objc[14697]: Class WebSwapCGLLayer is implemented in both /System/Library/Frameworks/WebKit.framework/Versions/A/Frameworks/WebCore.framework/Versions/A/Frameworks/libANGLE-shared.dylib (0x7ffb59a1b948) and /Applications/Google Chrome.app/Contents/Frameworks/Google Chrome Framework.framework/Versions/106.0.5249.119/Libraries/libGLESv2.dylib (0x1103af668). One of the two will be used. Which one is undefined.
# [1019/121724.896883:INFO:headless_shell.cc(660)] Written to file /var/folders/0r/d390l7l966lbz2f5k72v_24h0000gn/T/tmpgs_6vzzi/temp.png.

# %%
# manual transmission is lower than the other two types

df.groupby('transmission').mean()
# Out:
#                      year         price       mileage         tax        mpg  \
# transmission
# Automatic     2017.510340  28204.750000  21359.902880  149.411004  46.214660
# Manual        2016.393912  16101.033417  30981.888075   97.119478  56.758801
# Semi-Auto     2017.651629  27161.781676  19953.927318  143.517126  46.918992
#
#               engineSize
# transmission
# Automatic       2.187038
# Manual          1.635523
# Semi-Auto       2.096547

# %%
df['fuelType'].value_counts() / len(df)
# Out:
# Diesel    0.522778
# Petrol    0.474597
# Hybrid    0.002625
# Name: fuelType, dtype: float64

# %%
# lots of interesting correlations here

df.groupby('fuelType').mean()
# Out:
#                  year         price       mileage         tax         mpg  \
# fuelType
# Diesel    2016.846692  23237.516227  30220.968263  119.656625   54.240237
# Hybrid    2017.428571  30191.750000  28887.892857   72.678571  150.221429
# Petrol    2017.378629  22480.908355  18863.487656  133.306340   46.397511
#
#           engineSize
# fuelType
# Diesel      2.144379
# Hybrid      1.714286
# Petrol      1.696544

# %% [markdown]
# **Continuous Features**<br>
# There are 5 continuous features: year, mileage, tax, mpg, and engineSize. For each I check the distribution and its relation with price

# %%
d = pd.DataFrame(df['year'].describe())
d.columns = ['Year']
dfi.export(d, "../figures/Tables/describe_year_table.png")
# Out:
# objc[14707]: Class WebSwapCGLLayer is implemented in both /System/Library/Frameworks/WebKit.framework/Versions/A/Frameworks/WebCore.framework/Versions/A/Frameworks/libANGLE-shared.dylib (0x7ffb59a1b948) and /Applications/Google Chrome.app/Contents/Frameworks/Google Chrome Framework.framework/Versions/106.0.5249.119/Libraries/libGLESv2.dylib (0x10ec2f668). One of the two will be used. Which one is undefined.
# [1019/121725.531933:INFO:headless_shell.cc(660)] Written to file /var/folders/0r/d390l7l966lbz2f5k72v_24h0000gn/T/tmpqs1oxxr_/temp.png.

# %%
sb.histplot(df['year'], discrete = True)
plt.xlabel('Year')
plt.title('Count')
plt.savefig('../figures/car_year_counts.png')

# %%
d = pd.DataFrame(df['mileage'].describe())
d.columns = ['Mileage']
dfi.export(d, "../figures/Tables/describe_mileage_table.png")
# Out:
# objc[14720]: Class WebSwapCGLLayer is implemented in both /System/Library/Frameworks/WebKit.framework/Versions/A/Frameworks/WebCore.framework/Versions/A/Frameworks/libANGLE-shared.dylib (0x7ffb59a1b948) and /Applications/Google Chrome.app/Contents/Frameworks/Google Chrome Framework.framework/Versions/106.0.5249.119/Libraries/libGLESv2.dylib (0x1121bf668). One of the two will be used. Which one is undefined.
# [1019/121726.255648:INFO:headless_shell.cc(660)] Written to file /var/folders/0r/d390l7l966lbz2f5k72v_24h0000gn/T/tmpdylsx2d9/temp.png.

# %%
sb.histplot(df['mileage'])
plt.xlabel('Mileage')
plt.title('Mileage Distribution')
plt.savefig('../figures/mileage_counts.png')

# %%
sb.histplot(np.log(df['mileage']))
plt.xlabel('Logged Mileage')
plt.ylabel('Count')
plt.title('Logged Mileage Distribution')
plt.savefig('../figures/logged_mileage_counts.png')

# %%
sb.histplot(np.sqrt(df['mileage']))
plt.xlabel('Square Root of Mileage')
plt.ylabel('Count')
plt.title('Mileage square root Distribution')
plt.savefig('../figures/sqrt_mileage_counts.png')

# %%
df['tax'].describe()
# Out:
# count    10668.000000
# mean       126.011436
# std         67.170294
# min          0.000000
# 25%        125.000000
# 50%        145.000000
# 75%        145.000000
# max        580.000000
# Name: tax, dtype: float64

# %%
sb.histplot(df['tax'], bins = 15)
plt.xlabel('Tax Distribution')
plt.ylabel('Count')
plt.title('Tax Distribution')
plt.savefig('../figures/tax_distribution.png')

# %%
df['engineSize'].describe()
# Out:
# count    10668.000000
# mean         1.930709
# std          0.602957
# min          0.000000
# 25%          1.500000
# 50%          2.000000
# 75%          2.000000
# max          6.300000
# Name: engineSize, dtype: float64

# %%
sb.histplot(df['engineSize'], bins = 15)
plt.xlabel('Engine Size Distribution')
plt.ylabel('Count')
plt.title('Engine Size Distribution')
plt.savefig('../figures/engine_size_distribution.png')

# %% [markdown]
# **Continuous features vs. price**

# %%
# year + mileage could use some feature engineering, which I do in Preprocessing

pd.plotting.scatter_matrix(df)
plt.savefig('../figures/scatter_matrix.png')

# %%
sb.scatterplot(df, x='mileage', y = 'price')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.title('Price Distribution by Mileage')
plt.savefig('../figures/price_by_mileage.png')

# %%
sb.boxplot(df[['price','transmission']], x = 'transmission', y = 'price', palette = 'colorblind', width = .5)
plt.xlabel('Transmission Type')
plt.title('Price Distribution by Transmission Type')
plt.savefig('../figures/price_by_transmission.png')

# %%
# lots of good variation here to exploit

df[['price','model']].boxplot(by='model')
plt.xlabel('Car Model')
plt.ylabel('Price')
plt.title('Price Distribution by Model')
plt.savefig('../figures/price_by_model_distribution.png')
plt.show()

# %%
df[['price','transmission']].boxplot(by='transmission')
plt.xlabel('Transmission')
plt.ylabel('Price')
plt.title('Price Distribution by Transmission')
plt.savefig('../figures/price_by_transmission_distribution.png')
plt.show()

dataset = [np.log(df[df['transmission']=='Automatic']['price'].values),
           np.log(df[df['transmission']=='Manual']['price'].values),
           np.log(df[df['transmission']=='Semi-Auto']['price'].values)]

plt.violinplot(dataset = dataset)
plt.xticks([1,2, 3],['Automatic','Manual','Semi-Auto'])
plt.xlabel('Transmission')
plt.ylabel('Logged Price')
plt.title('Price Distribution by Transmission')
plt.savefig('../figures/price_by_transmission_distribution_violin.png')
plt.show()

plt.show()

# %%
# check correlations before doing any encoding, feature engineering

corr_m = df.corr()
mask = np.triu(corr_m)

ax = sb.heatmap(corr_m, annot=True, center = 0,mask = mask, vmin = -1, vmax = 1)
plt.savefig('../figures/early_correlation_matrix.png')
